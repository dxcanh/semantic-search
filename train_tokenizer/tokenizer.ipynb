# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp311-cp311-win_amd64.whl.metadata (8.3 kB)
# Downloading sentencepiece-0.2.0-cp311-cp311-win_amd64.whl (991 kB)
#    ---------------------------------------- 0.0/991.5 kB ? eta -:--:--
#    ---------------------------------------- 10.2/991.5 kB ? eta -:--:--
#    ---------------------------------------- 10.2/991.5 kB ? eta -:--:--
#    - ------------------------------------- 41.0/991.5 kB 245.8 kB/s eta 0:00:04
#    -- ------------------------------------ 61.4/991.5 kB 363.1 kB/s eta 0:00:03
#    -- ------------------------------------ 61.4/991.5 kB 363.1 kB/s eta 0:00:03
#    ----- -------------------------------- 143.4/991.5 kB 532.5 kB/s eta 0:00:02
#    ------ ------------------------------- 163.8/991.5 kB 544.7 kB/s eta 0:00:02
#    ------ ------------------------------- 163.8/991.5 kB 544.7 kB/s eta 0:00:02
#    -------- ----------------------------- 225.3/991.5 kB 528.4 kB/s eta 0:00:02
#    ---------- --------------------------- 286.7/991.5 kB 609.0 kB/s eta 0:00:02
#    ----------- -------------------------- 307.2/991.5 kB 633.2 kB/s eta 0:00:02
#    ------------- ------------------------ 358.4/991.5 kB 654.4 kB/s eta 0:00:01
#    ------------- ------------------------ 358.4/991.5 kB 654.4 kB/s eta 0:00:01
#    ------------- ------------------------ 358.4/991.5 kB 654.4 kB/s eta 0:00:01
#    -------------- ----------------------- 378.9/991.5 kB 548.6 kB/s eta 0:00:02
#    --------------- ---------------------- 399.4/991.5 kB 552.7 kB/s eta 0:00:02
#    --------------- ---------------------- 409.6/991.5 kB 543.3 kB/s eta 0:00:02
#    ---------------- --------------------- 440.3/991.5 kB 529.0 kB/s eta 0:00:02
#    ------------------ ------------------- 491.5/991.5 kB 559.6 kB/s eta 0:00:01
#    ------------------- ------------------ 512.0/991.5 kB 563.1 kB/s eta 0:00:01
#    -------------------- ----------------- 522.2/991.5 kB 536.7 kB/s eta 0:00:01
#    --------------------- ---------------- 563.2/991.5 kB 544.3 kB/s eta 0:00:01
#    --------------------- ---------------- 573.4/991.5 kB 537.9 kB/s eta 0:00:01
#    --------------------- ---------------- 573.4/991.5 kB 537.9 kB/s eta 0:00:01
#    --------------------- ---------------- 573.4/991.5 kB 537.9 kB/s eta 0:00:01
#    ----------------------- -------------- 604.2/991.5 kB 506.8 kB/s eta 0:00:01
#    ------------------------- ------------ 675.8/991.5 kB 538.9 kB/s eta 0:00:01
#    ----------------------------- -------- 757.8/991.5 kB 583.1 kB/s eta 0:00:01
#    ------------------------------- ------ 809.0/991.5 kB 608.3 kB/s eta 0:00:01
#    -------------------------------- ----- 849.9/991.5 kB 603.7 kB/s eta 0:00:01
#    ---------------------------------- --- 901.1/991.5 kB 626.5 kB/s eta 0:00:01
#    ----------------------------------- -- 931.8/991.5 kB 640.9 kB/s eta 0:00:01
#    ------------------------------------ - 952.3/991.5 kB 614.9 kB/s eta 0:00:01
#    -------------------------------------  983.0/991.5 kB 622.4 kB/s eta 0:00:01
#    -------------------------------------- 991.5/991.5 kB 621.5 kB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.0

# %%
from tokenizers import Tokenizer, models, \
    trainers, normalizers, pre_tokenizers, processors, decoders
import sentencepiece as spm

# %% [markdown]
# # Prepare corpus for training tokenizer

# %%
with open('E:\Python\DL\semantic-search\msmarco-data\collection.tsv', 'r') as rf, open('E:\Python\DL\semantic-search\msmarco-data\collection_corpus.txt', 'w') as wf:
    for line in rf.readlines():
        wf.write(line.split('\t')[1])

# %%
with open('E:\Python\DL\semantic-search\msmarco-data\queries.train.tsv', 'r') as rf, open('E:\Python\DL\semantic-search\msmarco-data\queries.train_corpus.txt', 'w') as wf:
    for line in rf.readlines():
        wf.write(line.split('\t')[1])

# %%
with open('E:\Python\DL\semantic-search\queries\queries.dev.tsv', 'r') as rf, open('E:/Python/DL/semantic-search/queries/raw_texts/queries.dev_corpus.txt', 'w') as wf:
    for line in rf.readlines():
        wf.write(line.split('\t')[1])

# %%
with open('E:\Python\DL\semantic-search\queries\queries.eval.tsv', 'r') as rf, open('E:/Python/DL/semantic-search/queries/raw_texts/queries.eval_corpus.txt', 'w') as wf:
    for line in rf.readlines():
        wf.write(line.split('\t')[1])

# %% [markdown]
# # Tokenizer training

# %% [markdown]
# ## Huggingface tokenizer

# %% [markdown]
# ### BPE tokenizer

# %%
bpe_tokenizer = Tokenizer(models.BPE())
bpe_tokenizer.normalizer = normalizers.NFC()
bpe_tokenizer.pre_tokenizer = pre_tokenizers.Whitespace()

bpe_tokenizer.decoder = decoders.WordPiece('@@')
trainer = trainers.BpeTrainer(special_tokens=[
    '[UNK]',
    '[CLS]',
    '[SEP]',
    '[PAD]'],
    unknow_token='[UNK]',
    vocab_size=32000,
    min_frequency=0,
    continuing_subword_prefix='@@')

# %%
files = [f'E:/Python/DL/semantic-search/queries/raw_texts/{file}.txt' for file in ['collection_corpus', 'queries.train_corpus', 'queries.dev_corpus', 'queries.eval_corpus']]
bpe_tokenizer.train(files=files, trainer=trainer)

# %%
print(bpe_tokenizer.encode('Hi i am a student. My name is Hai.').tokens)
print(bpe_tokenizer.encode('Hi i am a studen. My name is Hai.').ids)
# Out:
# ['Hi', 'i', 'am', 'a', 'student', '.', 'My', 'name', 'is', 'H', '@@ai', '.']
# [9776, 75, 884, 67, 1278, 582, 16, 2512, 874, 589, 42, 2220, 16]

# %%
bpe_tokenizer.decode([9776, 75, 884, 67, 3483, 16, 2512, 874, 589, 42, 2220, 16])
# Out:
# 'Hi i am a student. My name is Hai.'

# %% [markdown]
# ### WordPiece tokenizer

# %%
# WP tokenizer inspired by BERT tokenizer
wp_tokenizer = Tokenizer(models.WordPiece())
wp_tokenizer.normalizer = normalizers.Sequence([normalizers.NFC(),
                                                normalizers.Lowercase(),
                                                normalizers.StripAccents()])
wp_tokenizer.pre_tokenizer = pre_tokenizers.Whitespace()
wp_tokenizer.decoder = decoders.WordPiece()
wp_tokenizer.post_processor = processors.TemplateProcessing(
    single='[CLS] $A [SEP]',
    pair="[CLS] $A [SEP] $B:1 [SEP]:1",
    special_tokens=[
        ('[CLS]', 1),
        ('[SEP]', 2),
    ],
)
trainer = trainers.WordPieceTrainer(special_tokens=[
    '[UNK]',
    '[CLS]',
    '[SEP]',
    '[PAD]'],
    unknow_token='[UNK]',
    vocab_size=32000,
    min_frequency=0,)

# %%
files = [f'E:/Python/DL/semantic-search/queries/raw_texts/{file}.txt' for file in ['collection_corpus', 'queries.train_corpus', 'queries.dev_corpus', 'queries.eval_corpus']]
wp_tokenizer.train(files=files, trainer=trainer)

# %%
wp_tokenizer.get_vocab()
# Out:
# {'instrumental': 18441,
#  '##ass': 704,
#  'coldest': 10873,
#  'poe': 22084,
#  'subunits': 24732,
#  'kary': 19885,
#  '##gae': 23172,
#  'accounting': 4593,
#  'amusement': 21288,
#  'treaty': 6775,
#  '##ced': 1150,
#  '##odys': 31880,
#  'amphib': 12863,
#  'marit': 18086,
#  'prayer': 19281,
#  '##atorship': 29121,
#  'firef': 8506,
#  '##ulsion': 12434,
#  'seems': 6248,
#  'vibrations': 18539,
#  'daylight': 6026,
#  'verbal': 12688,
#  'official': 3292,
#  'prevented': 19463,
#  'premier': 8878,
#  'reflecting': 18528,
#  'marquez': 31921,
#  'palpitations': 19767,
#  'covering': 8317,
#  '##erman': 13420,
#  'shoreline': 22842,
#  'thatch': 29878,
#  'practice': 3389,
#  '##etal': 31170,
#  '##worts': 28733,
#  'stabilization': 29754,
#  'replenish': 31421,
#  'hernia': 8195,
#  'ensures': 15830,
#  '##horn': 17334,
#  '(%': 23465,
#  '##nels': 27279,
#  'paternal': 24722,
#  'radius': 12424,
#  'ranked': 7367,
#  'whip': 12489,
#  'monouns': 23669,
#  'interference': 14934,
#  'burg': 16351,
#  '##md': 9480,
#  'delinquency': 24067,
#  'qld': 25692,
#  'emphyse': 16134,
#  'ovum': 25810,
#  'six': 2468,
#  '##pen': 21550,
#  '##ニ': 439,
#  's7': 30485,
#  'initiatives': 20937,
#  'manu': 2568,
#  '##mill': 9327,
#  'cochle': 22073,
#  'kodiak': 28147,
#  'okeechobee': 31804,
#  'dj': 10677,
#  'institutions': 8715,
#  'northeastern': 16183,
#  'reag': 22881,
#  '##bly': 22457,
#  'telescope': 18220,
#  '##ll': 989,
#  'longmire': 24792,
#  'inspect': 9004,
#  'commence': 22242,
#  'gaelic': 11570,
#  'passcode': 23685,
#  'abd': 20616,
#  'calip': 25544,
#  'unusual': 8708,
#  'barrett': 26415,
#  'distress': 13346,
#  'shin': 16035,
#  'staggered': 27912,
#  'render': 11650,
#  'bab': 1378,
#  '1948': 17033,
#  'cinema': 19237,
#  'gh': 5415,
#  'judge': 5818,
#  'tum': 3648,
#  'intu': 17947,
#  'electrodes': 24045,
#  'cultivate': 29466,
#  'robes': 31655,
#  '##itonin': 29589,
#  'hiking': 17259,
#  'perpendicular': 16018,
#  'illinois': 3586,
#  'separate': 4468,
#  'burgers': 14503,
#  '##vern': 1488,
#  'kil': 3291,
#  'scheduling': 16561,
#  '311': 30014,
#  'bost': 5156,
#  '786': 21385,
#  '##izard': 9345,
#  '181': 28036,
#  'ionizing': 28602,
#  'extremely': 6092,
#  'honest': 13318,
#  '##angular': 10328,
#  'pons': 25511,
#  'sylvester': 31437,
#  'ferris': 25816,
#  'buy': 1831,
#  'series': 2339,
#  'sad': 7041,
#  'heâ': 14035,
#  'level': 1142,
#  'ganglion': 24557,
#  '##atadine': 23010,
#  '##ractice': 18497,
#  'lynx': 31026,
#  '##tain': 1805,
#  '##uke': 22864,
#  'macaroni': 23456,
#  'nomadic': 30043,
#  'miscarriage': 13041,
#  'volc': 4734,
#  'scoring': 13659,
#  'kittens': 9610,
#  '##mic': 5582,
#  'lupin': 30377,
#  'grants': 10666,
#  '##apia': 20421,
#  '##ì': 363,
#  '##\x87': 391,
#  'complication': 16671,
#  'edited': 15208,
#  'a2': 19589,
#  'onions': 7692,
#  'skateboard': 25479,
#  'pseudoephedrine': 26747,
#  'clyde': 30416,
#  'drones': 30139,
#  'monoxide': 11607,
#  'flat': 3639,
#  'seventy': 25468,
#  'laminate': 11645,
#  'runtime': 24652,
#  'codons': 24182,
#  'cleanup': 22106,
#  'propelled': 31282,
#  'cypr': 22255,
#  'evacuation': 25090,
#  'odys': 19318,
#  'ame': 27534,
#  'screenshot': 14747,
#  'laboratories': 19834,
#  'incline': 18083,
#  '##^': 376,
#  'vermont': 11491,
#  'acrob': 14615,
#  '##ameter': 27743,
#  'von': 14027,
#  'hyd': 2165,
#  'artist': 5940,
#  '##orro': 21682,
#  '##rael': 8828,
#  'clavicle': 22013,
#  '##box': 3709,
#  'cerebell': 17563,
#  'ballet': 17229,
#  'baccala': 28584,
#  'exhaust': 7541,
#  '##asing': 3257,
#  'immigrants': 10883,
#  '##vania': 4450,
#  'apostrophe': 21277,
#  'optional': 11162,
#  '5g': 24577,
#  'steelers': 24029,
#  '##kt': 28191,
#  'deed': 6486,
#  'hygienist': 14176,
#  '##fet': 30204,
#  'popul': 5936,
#  'mcle': 22319,
#  '##ek': 6904,
#  'cucumber': 12382,
#  'अ': 197,
#  '1990': 9246,
#  'stained': 21495,
#  'asbestos': 14177,
#  'relaxation': 18118,
#  'zambia': 31146,
#  'tow': 3538,
#  '##ancer': 11060,
#  '##isy': 11098,
#  'integer': 15400,
#  '##ogen': 3378,
#  'reduced': 5739,
#  'benadryl': 15498,
#  'assessing': 19840,
#  'papillomavirus': 23944,
#  'panc': 4288,
#  '##___': 6451,
#  '732': 31349,
#  'chromos': 3756,
#  'breed': 5053,
#  'น': 210,
#  'marsh': 7332,
#  'engra': 20157,
#  'spaw': 23030,
#  'laying': 10790,
#  'mccain': 24196,
#  'phylogen': 28617,
#  'cylinder': 8881,
#  'five': 2276,
#  '##ensions': 5097,
#  '530': 19671,
#  'battal': 23133,
#  'bodybuilding': 31429,
#  'hij': 26122,
#  '))': 15746,
#  'palliative': 28638,
#  '71': 6732,
#  'docs': 22603,
#  '##ilder': 25141,
#  'burgundy': 27903,
#  '***': 15620,
#  '##rolog': 17032,
#  'backgrounds': 26614,
#  'inequ': 17271,
#  'thom': 12158,
#  'bloated': 24033,
#  'flour': 5653,
#  'prostate': 4684,
#  'gav': 30169,
#  'sixth': 11660,
#  'mammograms': 24856,
#  'advoc': 7895,
#  'description': 4267,
#  'ae': 11146,
#  'living': 2241,
#  '##aken': 2666,
#  'crawl': 15462,
#  'allocation': 15342,
#  'governing': 14358,
#  'compute': 18836,
#  'burgl': 22646,
#  'cubism': 26439,
#  'scribe': 27535,
#  'marley': 23350,
#  '##rã': 27281,
#  'peacocks': 30401,
#  'shipments': 26687,
#  '##okin': 22349,
#  'samara': 30629,
#  '##ius': 3109,
#  'distinctions': 31232,
#  '##greg': 6531,
#  'denmark': 12113,
#  'cyber': 13155,
#  'pg': 14602,
#  'phill': 11294,
#  'dewey': 25532,
#  'crimson': 30341,
#  'task': 5581,
#  'spinning': 16005,
#  'exud': 26151,
#  'gorilla': 20570,
#  '##leur': 31502,
#  'trend': 9102,
#  '##otive': 8638,
#  'specially': 17223,
#  'dating': 7573,
#  'matters': 10170,
#  'cir': 1861,
#  'whooping': 17676,
#  'consistently': 14552,
#  'slew': 31271,
#  '##fil': 23796,
#  '##oin': 17134,
#  'marcus': 20040,
#  '2012': 3252,
#  'premium': 4619,
#  'characterize': 31976,
#  'chim': 9000,
#  '##pp': 592,
#  'colitis': 12161,
#  'octopus': 20583,
#  'landlords': 22549,
#  'princip': 3283,
#  'collar': 10077,
#  'offline': 14672,
#  'furosemide': 27012,
#  'sweater': 28299,
#  'ship': 4439,
#  '##rn': 29579,
#  'handlers': 31600,
#  'symph': 14193,
#  'obamacare': 17124,
#  'ladybug': 28888,
#  'acronyms': 13807,
#  'excell': 5651,
#  'oklah': 5903,
#  '##aux': 13670,
#  '##utes': 1508,
#  'compliant': 16645,
#  'top': 1328,
#  'solids': 13701,
#  'expedited': 18894,
#  '##acle': 5692,
#  'gond': 27264,
#  'β': 175,
#  '##ctive': 7782,
#  '##amp': 891,
#  'scored': 12186,
#  'warfarin': 16985,
#  '##ucch': 14944,
#  '##orse': 28736,
#  'sovereign': 14069,
#  'fools': 30104,
#  '##avirus': 15701,
#  'man': 615,
#  'sliding': 11964,
#  'mantis': 29455,
#  'impairment': 12827,
#  'hors': 5184,
#  'jagu': 24351,
#  'mortal': 21846,
#  '##ois': 13374,
#  'soaking': 20422,
#  'warning': 8354,
#  '##rive': 8431,
#  'rentals': 11918,
#  'machinery': 14272,
#  'cilantro': 16617,
#  'sedona': 22279,
#  'discussion': 8454,
#  'musculoskeletal': 19582,
#  'gainesville': 27603,
#  '##spray': 28371,
#  'desicc': 31564,
#  '%': 7,
#  'né': 24258,
#  'jock': 25681,
#  'aminotrans': 31396,
#  'snowfl': 30978,
#  '##ographers': 18120,
#  'awk': 25044,
#  'almanac': 28663,
#  'discs': 12219,
#  '##charged': 15998,
#  'lateral': 8778,
#  'sod': 2800,
#  '##ingham': 16208,
#  'tru': 8261,
#  'muslims': 17612,
#  'shoes': 5963,
#  '##cloud': 9876,
#  'agonist': 18722,
#  '##//': 3394,
#  'excessively': 25594,
#  'ars': 24616,
#  'vacc': 3359,
#  '##ibility': 3191,
#  'protection': 3951,
#  'hamstring': 19053,
#  '##ab': 560,
#  '1964': 12024,
#  'bo': 823,
#  '™': 227,
#  'blunt': 22347,
#  'fals': 23156,
#  'tolerant': 24052,
#  'clonazepam': 21149,
#  'emergency': 4579,
#  '##ely': 873,
#  'dru': 1668,
#  '##licit': 21211,
#  '¤\x95': 31480,
#  'parents': 3689,
#  '##paper': 8056,
#  'robotic': 25813,
#  '##astic': 2913,
#  'plate': 3222,
#  'bib': 7547,
#  'emig': 23666,
#  '##enders': 5465,
#  '##starch': 25708,
#  '##ine': 579,
#  'main': 1269,
#  'dian': 17265,
#  'emphasizes': 23447,
#  '##feed': 26257,
#  '##ersâ': 28211,
#  '954': 28342,
#  'behaviour': 13285,
#  'allah': 25737,
#  'azte': 21613,
#  'percutaneous': 29893,
#  '##lessly': 18770,
#  'juris': 7976,
#  'organizing': 18851,
#  'nbs': 25116,
#  'procl': 15337,
#  '##uits': 4825,
#  'relief': 6453,
#  'swallowed': 26978,
#  'signifies': 24638,
#  'passport': 3486,
#  'expands': 23209,
#  'march': 2830,
#  'slips': 28254,
#  'hyperp': 29123,
#  'defined': 2766,
#  'parasite': 16675,
#  'edition': 6961,
#  '##elyn': 21448,
#  'outbreak': 15637,
#  'virginia': 3468,
#  '(+': 14875,
#  'cec': 17185,
#  'unsure': 23106,
#  'chairs': 14301,
#  'collins': 10791,
#  '##orms': 5382,
#  '350': 6143,
#  'collapse': 13352,
#  'lat': 1808,
#  'dd': 10656,
#  'mushrooms': 10156,
#  '##trak': 19407,
#  'smartphones': 20462,
#  'reasoning': 13546,
#  '##aped': 22478,
#  'evaporate': 26728,
#  'placental': 29995,
#  'inhaler': 19487,
#  'african': 4455,
#  'metabolic': 8310,
#  '##pre': 4176,
#  'standby': 20736,
#  '##valent': 7939,
#  '##entown': 22598,
#  'marqu': 25369,
#  'tubman': 29390,
#  'maturity': 11405,
#  'mick': 15139,
#  'net': 1232,
#  'ritual': 16742,
#  'without': 1568,
#  'mckinley': 20101,
#  'foreclosed': 30414,
#  'snorkeling': 31427,
#  'magna': 23376,
#  'erisa': 24484,
#  'bennett': 22832,
#  'soap': 5884,
#  'bism': 14925,
#  '2015': 1910,
#  'gamet': 23581,
#  '##ingu': 5543,
#  'vivid': 25334,
#  '##oy': 1044,
#  'lexmark': 29171,
#  'seligman': 29448,
#  'obsessive': 30420,
#  'qvar': 31844,
#  'dermal': 19483,
#  'pratt': 27754,
#  'repairs': 10750,
#  'hepburn': 27424,
#  'bullf': 22954,
#  'recognised': 23559,
#  'dcis': 30993,
#  'harlem': 20266,
#  'psoriatic': 30453,
#  '##othermia': 22498,
#  'montg': 11126,
#  'sluggish': 29635,
#  'veteran': 10206,
#  'veh': 2210,
#  'ka': 7254,
#  'comply': 17344,
#  '|': 68,
#  'welding': 9647,
#  'tanzania': 21656,
#  'م': 195,
#  'hills': 6355,
#  'value': 1843,
#  'converter': 8781,
#  'rt': 10236,
#  'circum': 5932,
#  'pathogens': 14631,
#  'wherever': 17945,
#  'drizzle': 23215,
#  '##ye': 23630,
#  'almond': 8847,
#  'rhetorical': 18547,
#  'corporal': 26437,
#  'lyric': 11249,
#  'cookie': 10982,
#  '##mare': 23794,
#  'inhalation': 16732,
#  'maximize': 15080,
#  'corruption': 16286,
#  'compartment': 18129,
#  'billie': 29093,
#  'fort': 3151,
#  '##icans': 21072,
#  'dilaudid': 31822,
#  'detroit': 8210,
#  'ez': 14649,
#  '##cles': 2087,
#  'mildew': 22281,
#  'ber': 4353,
#  'copied': 16707,
#  'infusion': 11606,
#  'positions': 7291,
#  'sharepoint': 15764,
#  'distort': 30878,
#  'reticular': 26402,
#  'challenger': 20900,
#  'hcl': 12385,
#  '##gow': 22218,
#  'qin': 30784,
#  'fc': 12832,
#  'bras': 21202,
#  'arthropods': 27219,
#  'intermediate': 11953,
#  '##icolor': 28388,
#  'subscriber': 24854,
#  '##vo': 10081,
#  '##gender': 14028,
#  'disagre': 25288,
#  'seymour': 22847,
#  'annual': 2275,
#  '##osevel': 8413,
#  'fluctu': 18062,
#  'mansl': 26375,
#  'availability': 8994,
#  'compos': 4113,
#  '##opes': 9392,
#  'gog': 18818,
#  'comets': 31180,
#  'landscape': 9211,
#  'tries': 15023,
#  'firmly': 22144,
#  'routers': 23387,
#  'evidence': 4369,
#  'dryer': 11636,
#  'difficile': 31999,
#  'key': 1950,
#  '##hots': 18825,
#  'adjective': 7337,
#  'dwi': 21137,
#  'broadcasting': 19867,
#  'nutrit': 17954,
#  'wide': 2874,
#  '##charging': 26238,
#  'bottles': 10749,
#  'pcr': 19392,
#  'intent': 8588,
#  'quar': 16699,
#  'historic': 7412,
#  'chernobyl': 28957,
#  'fair': 3070,
#  '##ril': 9671,
#  'restaur': 4016,
#  'muslim': 11684,
#  'doe': 17597,
#  'gypsum': 26107,
#  'sleeps': 30604,
#  'macrophages': 22844,
#  '##chemical': 24071,
#  'voice': 3834,
#  '##91': 25133,
#  '##+': 335,
#  'inulin': 19015,
#  'exceed': 8583,
#  'shall': 4793,
#  'imaging': 10425,
#  'plasma': 5795,
#  'graham': 15212,
#  'specs': 17950,
#  'fulton': 18727,
#  'fann': 24393,
#  'stigma': 22879,
#  '##ura': 5663,
#  '##osomal': 28214,
#  'compile': 25727,
#  'hat': 3783,
#  '##izers': 11199,
#  'italy': 4456,
#  'alloy': 15058,
#  'chond': 23025,
#  'attributed': 16491,
#  'explores': 22097,
#  '##urop': 6333,
#  'aquarius': 23268,
#  '##ational': 1059,
#  'nk': 25685,
#  'monmouth': 27777,
#  '\x84': 75,
#  '16': 1689,
#  'previous': 3788,
#  'arden': 29039,
#  'subway': 13093,
#  'webster': 11029,
#  '##rax': 14665,
#  '##master': 13449,
#  'puzzle': 16715,
#  '##hell': 10162,
#  'ud': 14485,
#  'relevance': 20166,
#  'easter': 13031,
#  '##<': 378,
#  'parasitic': 14910,
#  'ed': 1355,
#  'han': 10387,
#  'airborne': 20254,
#  'super': 1962,
#  'allele': 11575,
#  '##lr': 18144,
#  'optomet': 20880,
#  'coh': 21444,
#  '~': 70,
#  'variance': 11735,
#  '##ricted': 9943,
#  'acidity': 16058,
#  'appro': 1604,
#  '##iologist': 9635,
#  '##author': 18681,
#  'approaching': 22150,
#  'bromide': 25282,
#  'dominion': 29145,
#  'sulf': 5586,
#  'homelessness': 29481,
#  'accidentally': 20564,
#  '##bral': 6225,
#  'login': 10745,
#  'naval': 11574,
#  'dialect': 13279,
#  'ep': 1684,
#  'dye': 9549,
#  '##umid': 17941,
#  'appearances': 18866,
#  'ingrown': 19955,
#  'fore': 3347,
#  'peanut': 8511,
#  'epidural': 18615,
#  'alimentary': 28210,
#  'sisters': 13873,
#  'wrapping': 21764,
#  'forgot': 13325,
#  '189': 7266,
#  'bin': 8813,
#  'myco': 25960,
#  'cycl': 6900,
#  'struggles': 27656,
#  'petty': 20994,
#  'waver': 27361,
#  'pauline': 30046,
#  'filmed': 5732,
#  'humanity': 16054,
#  'spokes': 18529,
#  '##ep': 809,
#  'ع': 194,
#  'literal': 7520,
#  'venison': 23708,
#  '##amphetamine': 16105,
#  'slender': 19533,
#  'describ': 2074,
#  'honeys': 26287,
#  'shining': 20416,
#  'semiconductor': 19505,
#  'minim': 9544,
#  'demonstr': 7525,
#  'cargo': 10308,
#  'elastic': 9132,
#  'camb': 10452,
#  'alot': 23496,
#  'strengthening': 24541,
#  '352': 30616,
#  '##rell': 13686,
#  '##ware': 1840,
#  'macy': 20882,
#  'upload': 6280,
#  'casting': 16711,
#  '##iona': 29008,
#  '##olla': 23044,
#  'technique': 6449,
#  'trading': 7013,
#  'chambers': 12250,
#  '##bet': 21673,
#  '##oglobin': 5972,
#  '##umab': 19518,
#  '##itage': 8270,
#  'psychiatry': 23747,
#  'focuses': 10686,
#  'crested': 31212,
#  'forcing': 22599,
#  'almost': 3339,
#  'diy': 12752,
#  '##isha': 15433,
#  'pug': 28707,
#  'shotgun': 28332,
#  'seeds': 3923,
#  '386': 30639,
#  '##plain': 21572,
#  'ultr': 24316,
#  '##tled': 27957,
#  'chem': 1586,
#  'moreover': 20039,
#  '##imore': 10271,
#  'supported': 8088,
#  'cozumel': 26767,
#  'interventions': 21268,
#  'excretory': 27465,
#  'identifiers': 30597,
#  '##zal': 26571,
#  '##ipher': 6457,
#  'ische': 14766,
#  'firefight': 18891,
#  '##ison': 1800,
#  'displays': 10651,
#  'eukaryotes': 14515,
#  '##wei': 31546,
#  'trainers': 23092,
#  '##oosa': 21177,
#  'snapper': 30723,
#  'presumed': 28931,
#  '##ugal': 29346,
#  'amer': 16394,
#  'retreat': 16403,
#  'dom': 2147,
#  'derivative': 11258,
#  'unknown': 7877,
#  'potency': 24993,
#  'tate': 28447,
#  '##ww': 19516,
#  'hodgkin': 19997,
#  'binary': 10801,
#  'nuggets': 21518,
#  'furnish': 22949,
#  'rept': 12052,
#  'memphis': 12527,
#  'drumsticks': 24198,
#  'byz': 24126,
#  'glass': 2846,
#  'por': 5259,
#  'tubule': 19639,
#  '##23': 13526,
#  'priorities': 23257,
#  'latent': 15647,
#  'sprayed': 30660,
#  'preferred': 8207,
#  '##meal': 9548,
#  'paroxys': 26609,
#  'landown': 30910,
#  '‘': 219,
#  'orthopaedic': 27924,
#  'prescribe': 12146,
#  'claudication': 28152,
#  'chame': 21319,
#  'except': 4715,
#  'agents': 6292,
#  'knees': 11384,
#  'angeles': 5174,
#  'horizontally': 22440,
#  '10x': 31933,
#  'flooded': 21979,
#  'hume': 26405,
#  'enrolled': 11811,
#  'soc': 1293,
#  'seminal': 24680,
#  '##stream': 6755,
#  'beaut': 3251,
#  'austrian': 26897,
#  '##ographics': 10013,
#  '##onent': 13453,
#  'hematoma': 22409,
#  'alg': 5901,
#  'several': 2093,
#  'skeptic': 25051,
#  '##uitary': 8068,
#  '##ache': 2617,
#  'harrisburg': 23435,
#  'reds': 19534,
#  'countyâ': 28488,
#  'attaches': 14976,
#  'hendrix': 27869,
#  '##path': 25341,
#  'flask': 22071,
#  '##eys': 13049,
#  '##erty': 26395,
#  '##part': 10620,
#  'bose': 20814,
#  'deliver': 2945,
#  'exch': 13295,
#  '##omegal': 26592,
#  'fern': 8418,
#  'marri': 2300,
#  'networking': 11803,
#  'zurich': 21411,
#  'astron': 8070,
#  'credential': 10513,
#  'orchestra': 19078,
#  'herbal': 10593,
#  'violet': 17191,
#  '980': 25899,
#  '##rox': 9330,
#  'reve': 6024,
#  'known': 1260,
#  'allied': 14188,
#  'catch': 6459,
#  'behave': 21467,
#  'meanings': 5459,
#  'absorb': 4727,
#  'calculates': 21947,
#  'midsize': 28156,
#  '##amm': 1513,
#  'headings': 31245,
#  'marketing': 4756,
#  '##nal': 5031,
#  'proximal': 15956,
#  'orthopedic': 15467,
#  'crem': 12058,
#  'bernie': 17982,
#  'clarification': 30673,
#  'subun': 18029,
#  'opening': 4466,
#  'shouldn': 14336,
#  'dock': 9997,
#  '##gie': 8855,
#  'depp': 25711,
#  'loyal': 12254,
#  '##11': 4510,
#  'logging': 16659,
#  'grinder': 22737,
#  'deficiency': 4890,
#  'commercially': 16355,
#  'ort': 31879,
#  'scap': 13151,
#  '##tzer': 26807,
#  '##tern': 1890,
#  'pragm': 31702,
#  'dean': 12261,
#  'hematopo': 23584,
#  'karyotype': 25489,
#  'cem': 9436,
#  '##bn': 16089,
#  'catalyst': 14798,
#  'descended': 27357,
#  'clue': 14667,
#  'granulated': 26251,
#  'skill': 6328,
#  'humanitarian': 26199,
#  'rost': 27950,
#  'fibers': 6472,
#  'aden': 7408,
#  'protista': 29085,
#  'maytag': 31550,
#  '476': 29714,
#  'con': 533,
#  'parkway': 19828,
#  'garlic': 5596,
#  'valid': 4415,
#  'sugars': 8944,
#  'nam': 10034,
#  '##inis': 23011,
#  'curtail': 28248,
#  'copies': 8591,
#  'candida': 11205,
#  '##dog': 20410,
#  '\x9e': 100,
#  'efficient': 6368,
#  'includ': 895,
#  'verification': 10218,
#  'dukes': 24160,
#  'alta': 23804,
#  'braun': 28037,
#  'jan': 2509,
#  'internal': 3495,
#  'bould': 19672,
#  '##esha': 21234,
#  'fiss': 17864,
#  '##o': 252,
#  'dick': 11075,
#  '##------': 30980,
#  '##onate': 18829,
#  'kiss': 9619,
#  'twisted': 17115,
#  'dion': 24915,
#  'toasted': 31050,
#  'sahara': 15415,
#  'traction': 14285,
#  'lans': 19886,
#  'osmosis': 20684,
#  'frust': 15750,
#  'prere': 18748,
#  '##yle': 2258,
#  'crews': 30568,
#  '##icidal': 25523,
#  'leslie': 20668,
#  'support': 1646,
#  '##asta': 27523,
#  '##ball': 1791,
#  'metast': 14775,
#  'papa': 21246,
#  '239': 23699,
#  '##quit': 22066,
#  '##ng': 23480,
#  'townsend': 30680,
#  '##making': 21062,
#  'vegas': 4935,
#  'debated': 27812,
#  '##rots': 7996,
#  '##ice': 641,
#  'thrones': 10870,
#  'manufacturers': 8530,
#  'nad': 10363,
#  '##ancers': 18255,
#  'unsc': 22065,
#  'woke': 25514,
#  '1974': 12820,
#  '283': 27136,
#  'development': 2343,
#  'magnum': 25593,
#  'sprays': 25002,
#  'underway': 30873,
#  'inj': 2317,
#  'beyonce': 18390,
#  'gemstone': 16851,
#  'curve': 7228,
#  'alger': 21687,
#  'hone': 13908,
#  'bloating': 8682,
#  'childhood': 8112,
#  'tris': 22736,
#  'relo': 23835,
#  'renting': 16416,
#  'reinforced': 24731,
#  'award': 4688,
#  'infar': 16040,
#  'goes': 3741,
#  'antar': 13305,
#  'jour': 4325,
#  '##ipper': 11140,
#  'conjug': 15558,
#  'jurisd': 8563,
#  'pirate': 27884,
#  'theta': 31498,
#  'videos': 6256,
#  'veterans': 6995,
#  'lightheadedness': 20934,
#  'gram': 6006,
#  'glucosamine': 30758,
#  '##iday': 3480,
#  '##ulf': 3344,
#  'bounded': 23707,
#  'contraindicated': 28404,
#  '##agers': 13418,
#  'viral': 6216,
#  'exhausted': 30373,
#  'sex': 2233,
#  '##nt': 23479,
#  'indent': 15543,
#  'hanger': 28696,
#  '##oodle': 14327,
#  '##erate': 4581,
#  'penet': 11661,
#  '##ctory': 23324,
#  '##center': 20530,
#  'alber': 10541,
#  'bros': 15981,
#  'watts': 10450,
#  'trust': 3598,
#  'renter': 28560,
#  'unincorporated': 15697,
#  'humus': 21832,
#  'circular': 10380,
#  'accidental': 20291,
#  'eventually': 7323,
#  'humira': 27561,
#  'cells': 1300,
#  'suggested': 9667,
#  '##retion': 11086,
#  'claiming': 13706,
#  '##itoneal': 16503,
#  '##avia': 23662,
#  'caloric': 17970,
#  'family': 1523,
#  'bre': 1167,
#  '##iced': 5774,
#  'companies': 3112,
#  ...}

# %%
wp_tokenizer.encode('Hi i am a student. My name is Hai.').ids
# Out:
# [1, 6000, 49, 680, 41, 3160, 16, 826, 757, 475, 28219, 16, 2]

# %%
wp_tokenizer.decode([1, 6000, 49, 680, 41, 3160, 16, 826, 757, 475, 28219, 16, 2])
# Out:
# 'hi i am a student. my name is hai.'

# %%
wp_tokenizer.save('E:/Python/DL/semantic-search/save/tokenizer/wp_tokenizer_32k.json', True)

# %% [markdown]
# ### Unigram tokenizer

# %%
unigram_tokenizer = Tokenizer(models.Unigram())

trainer = trainers.UnigramTrainer(special_tokens=[
    '[UNK]',
    '[CLS]',
    '[SEP]',
    '[PAD]'],
    unk_token='[UNK]',
    vocab_size=32000,
    min_frequency=0)
unigram_tokenizer.pre_tokenizer = pre_tokenizers.ByteLevel()

# %%
files = [f'E:/Python/DL/semantic-search/queries/raw_texts/{file}.txt' for file in ['collection_corpus', 'queries.train_corpus', 'queries.dev_corpus', 'queries.eval_corpus']]
unigram_tokenizer.train(files=files, trainer=trainer)

# %%
unigram_tokenizer.__dir__()
# Out:
# ['__new__',
#  '__repr__',
#  '__str__',
#  '__getstate__',
#  '__setstate__',
#  '__getnewargs__',
#  'from_str',
#  'from_file',
#  'from_buffer',
#  'from_pretrained',
#  'to_str',
#  'save',
#  'num_special_tokens_to_add',
#  'get_vocab',
#  'get_added_tokens_decoder',
#  'get_vocab_size',
#  'enable_truncation',
#  'no_truncation',
#  'enable_padding',
#  'no_padding',
#  'encode',
#  'encode_batch',
#  'encode_batch_fast',
#  'decode',
#  'decode_batch',
#  'token_to_id',
#  'id_to_token',
#  'add_tokens',
#  'add_special_tokens',
#  'train',
#  'train_from_iterator',
#  'post_process',
#  'pre_tokenizer',
#  'truncation',
#  'post_processor',
#  'model',
#  'encode_special_tokens',
#  'normalizer',
#  'decoder',
#  'padding',
#  '__dict__',
#  '__doc__',
#  '__module__',
#  '__hash__',
#  '__getattribute__',
#  '__setattr__',
#  '__delattr__',
#  '__lt__',
#  '__le__',
#  '__eq__',
#  '__ne__',
#  '__gt__',
#  '__ge__',
#  '__init__',
#  '__reduce_ex__',
#  '__reduce__',
#  '__subclasshook__',
#  '__init_subclass__',
#  '__format__',
#  '__sizeof__',
#  '__dir__',
#  '__class__']

# %%
unigram_tokenizer.encode('Hi, i am a student. My name is Hai')
# Out:
# Encoding(num_tokens=14, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])

# %%
from transformers.tokenization_utils import PreTrainedTokenizer

# %% [markdown]
# ## SentencePiece tokenizer

# %% [markdown]
# ### BPE tokenizer

# %%
files = [f'E:/Python/DL/semantic-search/queries/raw_texts/{file}.txt' for file in ['collection_corpus', 'queries.train_corpus', 'queries.dev_corpus', 'queries.eval_corpus']]
spm.SentencePieceTrainer.Train(
    input=files,
    model_prefix='E:/Python/DL/semantic-search/save/tokenizer/spModel_bpe_8k',
    vocab_size=32000,
    pad_id=0,                
    unk_id=1,
    bos_id=2,
    eos_id=3,
    pad_piece='[PAD]',
    unk_piece='[UNK]',
    bos_piece='[CLS]',
    eos_piece='[SEP]',
    user_defined_symbols='[MASK]',
    model_type='bpe'
)
sp = spm.SentencePieceProcessor()

# %%
sp.load('E:/Python/DL/semantic-search/save/tokenizer/spModel_bpe_8k.model')
# Out:
# True

# %%
sp.encode_as_pieces('Hi i am a student, my name is Hai')
# Out:
# ['▁Hi', '▁i', '▁am', '▁a', '▁student', ',', '▁my', '▁name', '▁is', '▁H', 'ai']

# %% [markdown]
# ### Unigram tokenizer

# %%
files = [f'E:/Python/DL/semantic-search/queries/raw_texts/{file}.txt' for file in ['collection_corpus', 'queries.train_corpus', 'queries.dev_corpus', 'queries.eval_corpus']]
spm.SentencePieceTrainer.Train(
    input=files,
    model_prefix='E:/Python/DL/semantic-search/save/tokenizer/spModel_uni_8k',
    vocab_size=32000,
    pad_id=0,                
    unk_id=1,
    bos_id=2,
    eos_id=3,
    pad_piece='[PAD]',
    unk_piece='[UNK]',
    bos_piece='[CLS]',
    eos_piece='[SEP]',
    user_defined_symbols='[MASK]',
    model_type='unigram'
)
sp = spm.SentencePieceProcessor()

# %%
sp.load('E:/Python/DL/semantic-search/save/tokenizer/spModel_uni_8k.model')
sp.encode_as_pieces('Hi i am a student, my name is Hai')
# Out:
# ['▁Hi', '▁i', '▁am', '▁a', '▁student', ',', '▁my', '▁name', '▁is', '▁Hai']
